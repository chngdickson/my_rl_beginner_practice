# %%
import gym
import numpy as np
from stable_baselines3 import PPO, A2C, SAC, TD3, DQN
from stable_baselines3.common.env_util import make_vec_env

# %%
env = gym.make("Breakout-v4")
print(env.observation_space)
print(env.action_space)
# Out:
# Box(0, 255, (210, 160, 3), uint8)
# Discrete(4)

# %%
n_steps=
vec_env = make_vec_env("Breakout-v4", n_envs=16)
model = PPO("MlpPolicy", vec_env, n_steps=n_steps//16, verbose=1, device="cuda").learn(int(2e5))
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# -----------------------------
# | time/              |      |
# |    fps             | 290  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 1024 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 172       |
# |    iterations           | 2         |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 2048      |
# | train/                  |           |
# |    approx_kl            | 0.0181454 |
# |    clip_fraction        | 0.0696    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.38     |
# |    explained_variance   | 0.00037   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00555   |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -0.00455  |
# |    value_loss           | 2.85      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 152          |
# |    iterations           | 3            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0077037457 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000446    |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00085     |
# |    value_loss           | 0.0162       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 208         |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010972484 |
# |    clip_fraction        | 0.0271      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00482    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 0.0492      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 0.846       |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 5           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.011017897 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000488    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.029       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 6           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018789787 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 0.0234      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 7           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.012677747 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00181    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 0.0434      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 8           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009926818 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0279      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 0.0426      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 1.19        |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 9           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.015940081 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0431      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 0.0627      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 10          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009109849 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00729     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 0.0484      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 251          |
# |    ep_rew_mean          | 1.39         |
# | time/                   |              |
# |    fps                  | 131          |
# |    iterations           | 11           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0118452925 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000906     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 0.0349       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 251        |
# |    ep_rew_mean          | 1.39       |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 12         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00976155 |
# |    clip_fraction        | 0.0725     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0388     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00391   |
# |    value_loss           | 0.02       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 254         |
# |    ep_rew_mean          | 1.38        |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 13          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.015126465 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0608      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 0.0669      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 255         |
# |    ep_rew_mean          | 1.4         |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 14          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010818668 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.024       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.0583      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | 1.58        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 15          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.010470803 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 0.0455      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 265         |
# |    ep_rew_mean          | 1.58        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 16          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015176961 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0392      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 0.0406      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 272          |
# |    ep_rew_mean          | 1.67         |
# | time/                   |              |
# |    fps                  | 129          |
# |    iterations           | 17           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0051757665 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0125       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.0538       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | 1.67        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 18          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009762488 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0122      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.056       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | 1.68        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 19          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.009618237 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00711     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 0.058       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | 1.68        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 20          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011524137 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0175      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00835    |
# |    value_loss           | 0.0533      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 277         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 21          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.013442053 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0547      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00923    |
# |    value_loss           | 0.0737      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | 1.74        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 22          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014725457 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0127      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.048       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 1.78        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 23          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.010925069 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00508     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 0.0288      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 24          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013003572 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0319      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 0.0534      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 25          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.011417694 |
# |    clip_fraction        | 0.00332     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0144      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -3.95e-05   |
# |    value_loss           | 0.0477      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 26          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018221373 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0344      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 0.0395      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 27          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.006977398 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0237      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 0.0529      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 277          |
# |    ep_rew_mean          | 1.72         |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 28           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0111544905 |
# |    clip_fraction        | 0.0971       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00228     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00481     |
# |    value_loss           | 0.044        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 1.73         |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 29           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0064398684 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.855       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0291       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 0.043        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 280          |
# |    ep_rew_mean          | 1.75         |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 30           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0038020615 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0209       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 0.06         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 284          |
# |    ep_rew_mean          | 1.8          |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 31           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0058794897 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.709       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0162       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000458    |
# |    value_loss           | 0.0427       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 32          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003554104 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000503   |
# |    value_loss           | 0.0339      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 290          |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 33           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0021695197 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.0274       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 289          |
# |    ep_rew_mean          | 1.83         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 34           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0021751337 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.619       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00138      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 0.0287       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 292          |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 35           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0035139094 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0165       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 0.0449       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 1.84         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 36           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0033437796 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0253       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 0.0423       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 1.84         |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 37           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0025343604 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00221      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 0.0193       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 1.84         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 38           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0029537412 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00672      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 0.0223       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 310          |
# |    ep_rew_mean          | 1.9          |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 39           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0035135665 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00806      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 0.0397       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 315          |
# |    ep_rew_mean          | 1.87         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 40           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0044682957 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.761       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0119       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 0.0369       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 317        |
# |    ep_rew_mean          | 1.87       |
# | time/                   |            |
# |    fps                  | 125        |
# |    iterations           | 41         |
# |    time_elapsed         | 334        |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.00603933 |
# |    clip_fraction        | 0.0922     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.68      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00773    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0024    |
# |    value_loss           | 0.0191     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 321          |
# |    ep_rew_mean          | 1.9          |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 42           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0002198274 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0351       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.0397       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | 1.87         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 43           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0033974021 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.657       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00418      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 0.029        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 1.87         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 44           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0057926183 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.02         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 0.0346       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 1.91         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 45           |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0019917074 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.034        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000364    |
# |    value_loss           | 0.0388       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 1.88         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 46           |
# |    time_elapsed         | 376          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0046998933 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0172       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 0.0232       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 332          |
# |    ep_rew_mean          | 1.87         |
# | time/                   |              |
# |    fps                  | 125          |
# |    iterations           | 47           |
# |    time_elapsed         | 384          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0025254586 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0105       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000787    |
# |    value_loss           | 0.0354       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 1.83         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 48           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0022847597 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0146       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 0.0343       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | 1.82         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 49           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0027693247 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0222       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 0.0236       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 50           |
# |    time_elapsed         | 410          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0027263397 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0154      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 51          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.003596211 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.414      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 0.00817     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 1.77         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 52           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0023401072 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.365       |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0178       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000985    |
# |    value_loss           | 0.0159       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 1.75         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 53           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0008806102 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.359       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00737      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00039     |
# |    value_loss           | 0.0176       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | 1.73         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 54           |
# |    time_elapsed         | 444          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0012318685 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0121       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 0.0104       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | 1.71         |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 55           |
# |    time_elapsed         | 452          |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# |    approx_kl            | 0.0021302314 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.3         |
# ...
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.122        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -4.09e-08     |
# |    n_updates            | 1780          |
# |    policy_gradient_loss | -0.000196     |
# |    value_loss           | 4.63e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 180           |
# |    time_elapsed         | 1499          |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00020711229 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.12         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00581       |
# |    n_updates            | 1790          |
# |    policy_gradient_loss | 0.000175      |
# |    value_loss           | 2.02e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 181           |
# |    time_elapsed         | 1508          |
# |    total_timesteps      | 185344        |
# | train/                  |               |
# |    approx_kl            | 0.00057473767 |
# |    clip_fraction        | 0.0104        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.111        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000723     |
# |    n_updates            | 1800          |
# |    policy_gradient_loss | -0.00087      |
# |    value_loss           | 2.98e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 182           |
# |    time_elapsed         | 1516          |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00063784886 |
# |    clip_fraction        | 0.00928       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0953       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00423      |
# |    n_updates            | 1810          |
# |    policy_gradient_loss | -0.000533     |
# |    value_loss           | 1.33e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 589          |
# |    ep_rew_mean          | 1.41         |
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 183          |
# |    time_elapsed         | 1525         |
# |    total_timesteps      | 187392       |
# | train/                  |              |
# |    approx_kl            | 0.0002041356 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00153     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -4.28e-05    |
# |    value_loss           | 7.02e-07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | 1.41        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 184         |
# |    time_elapsed         | 1533        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.000517481 |
# |    clip_fraction        | 0.00879     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0915     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00666    |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.000438   |
# |    value_loss           | 3.48e-09    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 185           |
# |    time_elapsed         | 1542          |
# |    total_timesteps      | 189440        |
# | train/                  |               |
# |    approx_kl            | 0.00019699917 |
# |    clip_fraction        | 0.00439       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0779       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -8.47e-08     |
# |    n_updates            | 1840          |
# |    policy_gradient_loss | -0.000281     |
# |    value_loss           | 1.56e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 186           |
# |    time_elapsed         | 1551          |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 0.00019868388 |
# |    clip_fraction        | 0.00879       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0885       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000188      |
# |    n_updates            | 1850          |
# |    policy_gradient_loss | -0.00067      |
# |    value_loss           | 9.47e-07      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 589         |
# |    ep_rew_mean          | 1.41        |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 187         |
# |    time_elapsed         | 1560        |
# |    total_timesteps      | 191488      |
# | train/                  |             |
# |    approx_kl            | 0.000649192 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0768     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -6.2e-08    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 3.15e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 589          |
# |    ep_rew_mean          | 1.41         |
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 188          |
# |    time_elapsed         | 1568         |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0002076397 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0654      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00116     |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.000249    |
# |    value_loss           | 1.78e-08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 189           |
# |    time_elapsed         | 1577          |
# |    total_timesteps      | 193536        |
# | train/                  |               |
# |    approx_kl            | 0.00020917255 |
# |    clip_fraction        | 0.00313       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0548       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00262      |
# |    n_updates            | 1880          |
# |    policy_gradient_loss | -0.000224     |
# |    value_loss           | 1.2e-07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 190           |
# |    time_elapsed         | 1585          |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 0.00012878765 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0479       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.66e-07      |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | -4.98e-05     |
# |    value_loss           | 3.09e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 191           |
# |    time_elapsed         | 1594          |
# |    total_timesteps      | 195584        |
# | train/                  |               |
# |    approx_kl            | 0.00016002893 |
# |    clip_fraction        | 0.00166       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.039        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00636      |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -0.000167     |
# |    value_loss           | 4.37e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 589          |
# |    ep_rew_mean          | 1.41         |
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 192          |
# |    time_elapsed         | 1602         |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 5.090813e-05 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0407      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.53e-08     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -9.25e-05    |
# |    value_loss           | 1.63e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 193           |
# |    time_elapsed         | 1611          |
# |    total_timesteps      | 197632        |
# | train/                  |               |
# |    approx_kl            | 0.00015782833 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0363       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000497      |
# |    n_updates            | 1920          |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 4.22e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 194           |
# |    time_elapsed         | 1620          |
# |    total_timesteps      | 198656        |
# | train/                  |               |
# |    approx_kl            | 0.00020328956 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0348       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.04e-07      |
# |    n_updates            | 1930          |
# |    policy_gradient_loss | -7.25e-05     |
# |    value_loss           | 1.3e-07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 195           |
# |    time_elapsed         | 1629          |
# |    total_timesteps      | 199680        |
# | train/                  |               |
# |    approx_kl            | 1.4116522e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0334       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.17e-07      |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | 2.32e-05      |
# |    value_loss           | 3.74e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 1.41          |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 196           |
# |    time_elapsed         | 1638          |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 0.00013367872 |
# |    clip_fraction        | 0.00244       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0408       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.31e-07      |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -0.000372     |
# |    value_loss           | 5.57e-08      |
# -------------------------------------------
